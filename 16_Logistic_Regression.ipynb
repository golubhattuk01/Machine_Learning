# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1 = pd.read_csv("subs.csv")

# %%
df = df1[["Age" , "Purchased"]]

# %%
df.head()
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0
# 3   27          0
# 4   19          0

# %%
# check the graph is linearly separable or not
sns.scatterplot(x = "Age" , y = "Purchased" , data = df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x = df[["Age"]]
y = df["Purchased"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = .20 , random_state = 42)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test , y_test)*100
# Out:
# 91.25

# %%
sns.lineplot(x = "Age" , y = lr.predict(x) , data = df ,c = "r")
sns.scatterplot(x = "Age" , y = "Purchased" , data = df)
plt.show()

# %%
lr.predict([[35]])[0]
# Out:
# C:\Users\G\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0
