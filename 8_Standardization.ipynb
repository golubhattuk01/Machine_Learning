# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("loan.csv")

# %%
# what is does 
#  new val = (old_val - mean)/std of old_val
# no nature change just scaling of magnitude

# %%
ss1 =  StandardScaler()
ss2 =  MinMaxScaler()

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
ss1.fit(df[["ApplicantIncome"]])
ss2.fit(df[["ApplicantIncome"]])
# Out:
# MinMaxScaler()

# %%
df["scale_income1"] = pd.DataFrame(ss.transform(df[["ApplicantIncome"]]))
df["scale_income2"] = pd.DataFrame(ss.transform(df[["ApplicantIncome"]]))

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  scale_income1  scale_income2
# 0             1.0         Urban           Y       0.072991       0.072991
# ...

# %%
df["scale_income1"].describe()
# Out:
# count    6.140000e+02
# mean    -4.339634e-18
# std      1.000815e+00
# min     -8.606493e-01
# 25%     -4.138159e-01
# 50%     -2.606393e-01
# 75%      6.414426e-02
# max      1.238462e+01
# Name: scale_income1, dtype: float64

# %%
# the mean is approx 0  and varience is approx 1 which is squire of std daviation
plt.subplot(1,3,1)
sns.boxplot(x="CoapplicantIncome" , data = df)
plt.subplot(1,3,2)
sns.boxplot(x="scale_income1" , data = df)
plt.subplot(1,3,3)
sns.boxplot(x="scale_income2" , data = df)
plt.show()
# no difference in nature

# %%
# no difference in nature after scalling
# the mean is approx 0  and varience is approx 1 which is squire of std daviation
plt.subplot(1,3,1)
sns.histplot(x="CoapplicantIncome" , data = df)
plt.subplot(1,3,2)
sns.histplot(x="scale_income1" , data = df)
plt.subplot(1,3,3)
sns.histplot(x="scale_income2" , data = df)
plt.show()
# no difference in nature
