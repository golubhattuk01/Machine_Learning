# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
df = pd.read_csv("loan.csv")

# %%
order =[ ['Urban', 'Rural', 'Semiurban']]
oe = OrdinalEncoder(categories = order)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Property_Area
# 0             1.0         Urban           Y                2.0
# 1             1.0         Rural           N                0.0
# 2             1.0         Urban           Y                2.0
# 3             1.0         Urban           Y                2.0
# 4             1.0         Urban           Y                2.0

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df["New_Property_Area"] = oe.fit_transform(df[["Property_Area"]])

# %%
df[["Property_Area" , "New_Property_Area" ,"Education"]].head()
# Out:
#   Property_Area  New_Property_Area     Education
# 0         Urban                0.0      Graduate
# 1         Rural                1.0      Graduate
# 2         Urban                0.0      Graduate
# 3         Urban                0.0  Not Graduate
# 4         Urban                0.0      Graduate

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Property_Area
# 0             1.0         Urban           Y                2.0
# 1             1.0         Rural           N                0.0
# 2             1.0         Urban           Y                2.0
# 3             1.0         Urban           Y                2.0
# 4             1.0         Urban           Y                2.0
