# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("loan.csv")

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df["CoapplicantIncome"].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(x="CoapplicantIncome" , data = df)
plt.show()

# %%
# two method to remove outliers 
#  IQR
# z score methodp

# %%
sns.displot(df["CoapplicantIncome"])
plt.show()

# %%
sns.histplot(df["CoapplicantIncome"])
plt.show()

# %%
sns.boxplot(x="CoapplicantIncome" , data = df)
plt.show()

# %%
# first we need o1 and o3 point that is 25 and 75 percentile of box plot 
q1 = df["CoapplicantIncome"].quantile(0.25)
q3 = df["CoapplicantIncome"].quantile(0.75)
# the iqr is difference between them 
iqr = q3 - q1

# %%
max = q3 + (1.5*iqr)
min = q1 - (1.5*iqr)
min , max
# Out:
# (-3445.875, 5743.125)

# %%
df2 = df[df["CoapplicantIncome"]<max]
df2.shape
# Out:
# (596, 13)

# %%
sns.boxplot(x="CoapplicantIncome" , data = new_df)
plt.show()

# %%
# using z score method the min and max value
z_min = df["CoapplicantIncome"].mean() - (3*df["CoapplicantIncome"].std())
z_max = df["CoapplicantIncome"].mean() + (3*df["CoapplicantIncome"].std())
z_min , z_max
# Out:
# (-7157.4993096454655, 10399.990905699668)

# %%
df4 = df[df["CoapplicantIncome"]<z_max]

# %%
df["z_score"] = (df["CoapplicantIncome"]-df["CoapplicantIncome"].mean())/df["CoapplicantIncome"].std()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status   z_score
# 0             1.0         Urban           Y -0.554036
# ...

# %%
df3 = df[df["z_score"]<3]

# %%
df3.shape
# Out:
# (608, 14)

# %%
sns.boxplot(x="CoapplicantIncome" , data = df2)
plt.show()

# %%
sns.boxplot(x="CoapplicantIncome" , data = df3)
plt.show()

# %%
sns.boxplot(x="CoapplicantIncome" , data = df4)
plt.show()
