# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("subs.csv")

# %%
df.drop(columns=["User ID",	"Gender"], inplace = True)

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = .20 , random_state = 42)
lr = LogisticRegression()
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test , y_test)*100
# Out:
# 88.75

# %%
df["Purchased"].value_counts()
# count gap is too much , it may arise the data imbalance situation
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
from  imblearn.under_sampling import RandomUnderSampler

# %%
x= df.iloc[:,:-1]
y = df["Purchased"]

# %%
rus = RandomUnderSampler()
x_sam , y_sam = rus.fit_resample(x , y)

# %%
y_sam.value_counts()
# Out:
# Purchased
# 0    143
# 1    143
# Name: count, dtype: int64

# %% [markdown]
# # now 0 and 1 have the same number of value counts

# %%
x_train1 , x_test1 , y_train1 , y_test1 = train_test_split(x_sam , y_sam , test_size = .20 , random_state = 42)
lr1 = LogisticRegression()
lr1.fit(x_train1 , y_train1)
# Out:
# LogisticRegression()

# %%
lr1.score(x_test , y_test)*100
# Out:
# 88.75

# %% [markdown]
# <!-- the accuracy is improved -->

# %% [markdown]
# # the accucacy is improved

# %% [markdown]
# # over sampling

# %%
from  imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler()
x_sam2 , y_sam2 = ros.fit_resample(x , y)

# %%
y_sam2.value_counts()
# Out:
# Purchased
# 0    257
# 1    257
# Name: count, dtype: int64

# %% [markdown]
# # both has the same number of value counts (higher)

# %%
x_train2 , x_test2 , y_train2 , y_test2 = train_test_split(x_sam2 , y_sam2 ,test_size = .15 , random_state = 43)
lr2 = LogisticRegression()
lr2.fit(x_train2 , y_train2)
# Out:
# LogisticRegression()

# %%
lr2.score(x_test , y_test)*100
# Out:
# 87.5

# %% [markdown]
# # accuracy little lower
